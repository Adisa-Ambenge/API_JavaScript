# %% [markdown]
# <a href="https://colab.research.google.com/github/Adisa-Ambenge/API_JavaScript/blob/main/WEB_SCRAP_RW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Job in Rwanda

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
content_featured = requests.get('https://www.rssb.rw/scheme/ejo-heza').content

# %%
page_featured = BeautifulSoup(content_featured, 'html.parser')
adverts_all = page_featured.find_all('div', class_='schemeSlug__MarkdDownWrapper-sc-1duhq40-0 eNtKkH text-gray-color leading-7')

# %%
profile = adverts_all[0].find("p").text
profile
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-458331c8ef04> in <cell line: 1>()
# ----> 1 profile = adverts_all[0].find("p").text
#       2 profile
#
# IndexError: list index out of range

# %%
print(profile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fc68eba646f1> in <cell line: 1>()
# ----> 1 print(profile)
#
# NameError: name 'profile' is not defined

# %%
ejo_link = page_featured.find_all('div', class_='my-4')[0].find("a")['href']
ejo_link
# Out:
# 'https://ejoheza.gov.rw/'

# %%
ejo_questions = page_featured.find_all('div', class_='mt-4 pb-12')
ejo_questions
# Out:
# [<div class="mt-4 pb-12" id="scheme-info-holder"><div><div><div class="col"><div class="tabs"><div class="tab border-b border-secondary-border-color"><input id="schemeData-0" name="schemeData" type="radio"/><label class="tab-label text-gray-color font-segoe-regular" for="schemeData-0">What are the objectives of Ejo Heza?</label><div class="accordion__MarkdDownWrapper-sc-1oiojn9-0 dLPipc tab-content font-segoe-light"><ul>
#  <li>The culture of saving among the citizen/residents in Rwanda.</li>
#  <li>Universal access to pension and social security inclusion.</li>
#  <li>Financial inclusion.</li>
#  <li>Economic growth, poverty alleviation to attain higher standards of living</li>
#  </ul></div></div><div class="tab border-b border-secondary-border-color"><input id="schemeData-1" name="schemeData" type="radio"/><label class="tab-label text-gray-color font-segoe-regular" for="schemeData-1">Who can open an Ejo Heza account?</label><div class="accordion__MarkdDownWrapper-sc-1oiojn9-0 dLPipc tab-content font-segoe-light"><p>Any Rwandan citizen with a national ID issued by NIDA and any foreigner residing in Rwanda has the right to voluntarily open an Ejo Heza account. Members of the RSSB Pension Scheme or other voluntary schemes can also voluntarily open an Ejo Heza account to save additionally for their old age.</p></div></div><div class="tab border-b border-secondary-border-color"><input id="schemeData-2" name="schemeData" type="radio"/><label class="tab-label text-gray-color font-segoe-regular" for="schemeData-2">How can I open my Ejo Heza account and pay my contributions?</label><div class="accordion__MarkdDownWrapper-sc-1oiojn9-0 dLPipc tab-content font-segoe-light"><p>Your EjoHeza account will be linked to your permanent national Identity Card (NID) number. Your national ID number will remain your unique link to your Ejo eza account for the rest of your life. Your EjoHeza account and your savings will always remain in your name even if you change your job or your home over time. If you are an adult and have a permanent national ID issued by NIDA, you can open your Ejo Heza account free of cost using your own mobile phone by simply dialing *506# for MTN Rwanda and Airtel-Tigo and by following the simple prompts for registration and payment of contributions. You can also open your own EjoHeza account free of cost using a web browser on a smart phone or a computer by visiting <a href="www.ejoheza.gov.rw">EjoHeza</a>, clicking the “Register Now” button and following the simple prompts.</p></div></div><div class="tab border-b border-secondary-border-color"><input id="schemeData-3" name="schemeData" type="radio"/><label class="tab-label text-gray-color font-segoe-regular" for="schemeData-3">How is Ejo Heza different from the RSSB Pension Scheme?</label><div class="accordion__MarkdDownWrapper-sc-1oiojn9-0 dLPipc tab-content font-segoe-light"><p>Ejo Heza is a voluntary, government-sponsored scheme available to all the citizens of Rwanda. Anyone working in the formal or informal sector, either self-employed or working for someone else, can join the scheme. The RSSB pension Scheme on the other hand is compulsory and is only available to those who are employed in public or private sector enterprises. Ejo Heza is a defined contribution scheme whereas the RSSB pension scheme is a defined benefit scheme. Members in Ejo Heza will start receiving their monthly pension at 55 years of age whereas members in RSSB start receiving their monthly pension at 65 years or at early retirement of 60. RSSB contributions are a pre-defined percentage of salary and are deducted and remitted on a monthly basis. Ejo Heza members can decide how much they want to contribute and are also permitted to make contributions anytime (daily, weekly, monthly, quarterly or annually) as per their choice.</p></div></div><div class="tab border-b border-secondary-border-color"><input id="schemeData-4" name="schemeData" type="radio"/><label class="tab-label text-gray-color font-segoe-regular" for="schemeData-4">Why should a person who is already an RSSB Pension Scheme member also open an Ejo Heza account?</label><div class="accordion__MarkdDownWrapper-sc-1oiojn9-0 dLPipc tab-content font-segoe-light"><p>Today, most people live for around 20 years after they are old (retirement age). So you should save as much as you can while you are working to ensure that you have enough savings to last you for at least 20 years of expenses when you retire. So even if you are already saving in the RSSB pension scheme, putting aside some additional savings into your Ejo Heza account will ensure that you have sufficient savings for a secure and dignified retirement and do ...
#  <ul>
#  <li>A member who is in the third category of Ubudehe and has saved at least eighteen thousand (18,000) Rwandan francs has right to a Government contribution equal to fifty percent (50%) of his or her savings;</li>
#  <li>The Government's contribution to long term savings scheme mentioned cannot exceed eighteen thousand (18,000) Rwandan francs.</li>
#  <li>Ubudehe category 4 members who save RwF72,000 or more in Ejo Heza in a year shall also be eligible for the special insurance benefit during the following year. Therefore, if an Ubudehe category 4 member who had saved Rwf72,000 or more in a year, unfortunately passes away next year, the member's nominated beneficiary will be paid a one-time compensation of Rwf1,000,000 along with a one-time payment of Rwf250,000 towards the member's funeral expenses. The annual insurance premium will be paid by the Government on your behalf. Only Rwandan citizens with a permanent National ID (aged 16 years and above) issued by NIDA will be eligible for the life and funeral insurance benefits. N.B. The government co-contribution benefit will be paid into the Ejo Heza accounts of eligible members on an annual basis for the first 36 months following the date of launch of the Scheme.</li>
#  </ul>
#  <p><strong>Note:</strong> The life and funeral insurance benefits will also be available to eligible members on an annual basis for a total period of 36 months. The insurance benefits will however become available 12 months after the launch of the Scheme.</p></div></div></div></div></div></div></div>]

# %%
Questions = ejo_questions[0].find_all('label',class_= 'tab-label text-gray-color font-segoe-regular')
Questions =[question.text for question in Questions]
Questions

# %%
responses = ejo_questions[0].find_all('div',class_= 'accordion__MarkdDownWrapper-sc-1oiojn9-0 jrbBND tab-content font-segoe-light')
responses
# Out:
# []

# %%
responses = ejo_questions[0].find_all('div',class_= 'accordion__MarkdDownWrapper-sc-1oiojn9-0 jrbBND tab-content font-segoe-light')
responses = [response.text for response in responses]
responses
# Out:
# []

# %%
adverts_all[1].find_all('p')[0].find('span').getText()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-3070e7ddbcc3> in <cell line: 1>()
# ----> 1 adverts_all[1].find_all('p')[0].find('span').getText()
#
# IndexError: list index out of range

# %%
import requests #Fetch HTML Pages from the Web
from bs4 import BeautifulSoup #Extract information from HTML pages
import pandas as pd #organise our data into tabular/tables

# %%
#Fetch Website HTML content using request library
content_jobs = requests.get('https://www.jobinrwanda.com/jobs/all').content #Jobs
content_cons = requests.get('https://www.jobinrwanda.com/jobs/consultancy').content  #Consultations
content_tender = requests.get('https://www.jobinrwanda.com/jobs/tender').content #Tenders

# %%
content_jobs #SHow the raw html content of jobs
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n  <head>\n    <meta charset="utf-8"/>\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-42852300-1"></script>\n<script>window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)};gtag("js",new Date());gtag("set","developer_id.dMDhkMT",true);gtag("config","UA-42852300-1",{"groups":"default","anonymize_ip":true,"page_placeholder":"PLACEHOLDER_page_path"});</script>\n<meta name="description" content="Our jobs"/>\n<link rel="canonical" href="https://www.jobinrwanda.com/jobs/all"/>\n<meta name="Generator" content="Drupal 9 (https://www.drupal.org)"/>\n<meta name="MobileOptimized" content="width"/>\n<meta name="HandheldFriendly" content="true"/>\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"/>\n<meta http-equiv="x-ua-compatible" content="ie=edge"/>\n<link rel="icon" href="/favicon.ico" type="image/vnd.microsoft.icon"/>\n<script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};</script>\n\n    <title>Our jobs | Job in Rwanda</title>\n    <link rel="stylesheet" media="all" href="/core/A.assets,,_vendor,,_jquery.ui,,_themes,,_base,,_core.css,,qrxsj74+assets,,_vendor,,_jquery.ui,,_themes,,_base,,_autocomplete.css,,qrxsj74+assets,,_vendor,,_jquery.ui,,_themes,,_base,,_menu.css,,qrxsj74+modules,,_system,,_css,,_components,,_ajax-progress.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_align.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_autocomplete-loading.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_fieldgroup.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_container-inline.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_clearfix.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_details.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_hidden.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_item-list.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_js.module.css,,qrxsj74+modules,,_system,,_css,,_components,,_nowrap.module.css,,qrxsj74,Mcc.bAiscnSUJ-.css.pagespeed.cf.xYhGsgZBYw.css"/>\n\n\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" media="all" href="/A.core,,_modules,,_system,,_css,,_components,,_position-container.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_progress.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_reset-appearance.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_resize.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_sticky-header.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_system-status-counter.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_system-status-report-counters.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_system-status-report-general-info.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_tabledrag.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_tablesort.module.css,,qrxsj74+core,,_modules,,_system,,_css,,_components,,_tree-child.module.css,,qrxsj74+libraries,,_jquery.select2,,_dist,,_css,,_select2.min.css,,qrxsj74,Mcc.qv9IGVYSkw.css.pagespeed.cf.mfnJoVbSUP.css"/>\n\n\n\n\n\n\n\n\n\n\n\n<link rel="stylesheet" media="all" href="/A.modules,,_contrib,,_webform,,_css,,_webform.element.select2.css,,qrxsj74+libraries,,_jquery.intl-tel-input,,_build,,_css,,_intlTelInput.min.css,,qrxsj74+modules,,_contrib,,_adsense,,_css,,_adsense.module.css,,qrxsj74+core,,_modules,,_views,,_css,,_views.module.css,,qrxsj74+modules,,_contrib,,_webform,,_css,,_webform.form.css,,qrxsj74+modules,,_contrib,,_webform,,_css,,_webform.element.details.toggle.css,,qrxsj74+modules,,_contrib,,_webform,,_css,,_webform.element.message.css,,qrxsj74+core,,_assets,,_vendor,,_jquery.ui,,_themes,,_base,,_theme.css,,qrxsj74+modules,,_contrib,,_addtoany,,_css,,_addtoany.css,,qrxsj74+modules,,_contrib,,_back_to_top,,_css,,_back_to_top.css,,qrxsj74+t ...

# %%
page = BeautifulSoup(content_jobs, 'html.parser')

# %%
adverts = page.find_all('div', class_='card-body p-2')

# %%
adverts[0]
# Out:
# <div class="card-body p-2">
# <a href="/job/technical-advisor-inclusive-governancere-advertise"><h5 class="card-title"><span class="field field--name-title field--type-string field--label-hidden">Inclusive Governance –Technical Advisor(Re-advertised)</span>
# </h5></a>
# <p class="card-text">
# <a href="/employer/care-international-rwanda">CARE International Rwanda</a>  | <i class="fas fa-map-marker-alt"></i> Kigali  |
#               Published on 02-08-2023 |
#               Deadline <time class="datetime" datetime="2023-08-21T21:59:59Z">21-08-2023</time>
# <br/>
#                               Senior (5+ years of experience)<br/>
# <span class="badge badge-primary">Job</span>
# </p>
# </div>

# %%
adverts[0].find('p').find('br')
# Out:
# <br/>

# %%
adverts[0].find('span').getText() #Title of Each Job advert
adverts[0].find('a')['href']  #Link to the content of each job title
adverts[0].find('p').find('a') #Link to the Institution that has posted the advert
adverts[0].find('p').find('a').getText() #This is the name of the company
# Out:
# 'CARE International Rwanda'

# %%
df = pd.DataFrame()
df['link'] = None
df['title'] = None
df['company_link'] = None
df['company'] = None
df['type'] = None

# %%
l = ['a', 'v', 'b']
for index, item in enumerate(l):
  print(index, item)

#Short INtro to Enumerate
# Out:
# 0 a
# 1 v
# 2 b

# %%
l[0]  #list traversing
# Out:
# 'a'

# %%
def parse_content(content, advert_type):
  link = []
  title = []
  company = []
  company_link = []
  job_type = []
  for index, advert in enumerate(content):
    link.append(advert.find('a')['href'])
    title.append(advert.find('span').getText()) #GEt the title from
    company.append(str(advert.find('p').find('a').getText()))
    company_link.append(advert.find('p').find('a'))
    job_type.append(advert_type) #Whether its a job/consultacy/tender
  return link, title, company, company_link, job_type

# %%
#Jobs Advert
content_jobs_bs = BeautifulSoup(content_jobs, 'html.parser')
content_jobs_titles = content_jobs_bs.find_all('div', class_='card-body p-2')
df['link'], df['title'], df['company'], df['company_link'], df['type']= parse_content(content_jobs_titles, advert_type='Job')

# %%
df['link']
# Out:
# 0      /job/technical-advisor-inclusive-governancere-...
# 1                  /job/digitalization-technical-advisor
# 2                            /job/sales-representative-1
# 3                    /job/quality-assurance-specialist-0
# 4                                      /job/risk-manager
#                              ...
# 112      /index.php/job/tax-compliance-senior-specialist
# 113                        /job/nigeria-country-director
# 114    /index.php/job/global-research-and-evaluation-...
# 115    /index.php/job/nigeria-rural-retail-operations...
# 116    /job/global-monitoring-evaluation-and-learning...
# Name: link, Length: 117, dtype: object

# %%
list_description = []
for i in range(len(df)):
  link = 'https://www.jobinrwanda.com' + df['link'][i]
  print(link, i)
# Out:
# https://www.jobinrwanda.com/job/technical-advisor-inclusive-governancere-advertise 0
# https://www.jobinrwanda.com/job/digitalization-technical-advisor 1
# https://www.jobinrwanda.com/job/sales-representative-1 2
# https://www.jobinrwanda.com/job/quality-assurance-specialist-0 3
# https://www.jobinrwanda.com/job/risk-manager 4
# https://www.jobinrwanda.com/job/contract-officer-0 5
# https://www.jobinrwanda.com/job/marketing-representatives-0 6
# https://www.jobinrwanda.com/job/programme-manager-2 7
# https://www.jobinrwanda.com/job/project-manager-20 8
# https://www.jobinrwanda.com/job/rccdn-programme-coordinator-climate-just-communities-cjc 9
# https://www.jobinrwanda.com/job/rccdn-rwanda-climate-just-communities-administrative-assistant 10
# https://www.jobinrwanda.com/job/rccdn-rwanda-climate-just-communities-programme-accountant 11
# https://www.jobinrwanda.com/job/logistics-transport-facilitator 12
# https://www.jobinrwanda.com/job/wash-project-managercohers 13
# https://www.jobinrwanda.com/job/wash-project-managerangus 14
# https://www.jobinrwanda.com/job/wash-community-mobiliser-officer 15
# https://www.jobinrwanda.com/job/gender-wash-project-manager 16
# https://www.jobinrwanda.com/job/teaching-assistantship-mentor-0 17
# https://www.jobinrwanda.com/job/pashto-and-other-language-interpreter 18
# https://www.jobinrwanda.com/job/aquaponic-farm-officer-0 19
# https://www.jobinrwanda.com/job/distribution-wholesaler-manager-and-business-developer 20
# https://www.jobinrwanda.com/job/payments-ecosystem-services-pes-projects-senior-associate 21
# https://www.jobinrwanda.com/index.php/job/software-development-lead-odoo-solutions 22
# https://www.jobinrwanda.com/job/accounting-and-grants-specialist 23
# https://www.jobinrwanda.com/job/senior-sales-executive-0 24
# https://www.jobinrwanda.com/job/coffee-value-chain-expert 25
# https://www.jobinrwanda.com/job/monitoring-evaluation-and-learning-mel-fellows 26
# https://www.jobinrwanda.com/job/project-scheduler-and-cost-controller 27
# https://www.jobinrwanda.com/job/meal-officer 28
# https://www.jobinrwanda.com/job/project-officer-16 29
# https://www.jobinrwanda.com/job/treasury-accountant-0 30
# https://www.jobinrwanda.com/job/usaid-tlm-project-business-development-publishing-industry 31
# https://www.jobinrwanda.com/job/usaid-tlm-project-literacy-disability-inclusion-specialist 32
# https://www.jobinrwanda.com/index.php/job/usaid-tlm-project-publishing-capacity-development-specialist 33
# https://www.jobinrwanda.com/job/procurement-manager-11 34
# https://www.jobinrwanda.com/job/business-banker-muhanga-branch 35
# https://www.jobinrwanda.com/job/program-officer-ovc-dreams 36
# https://www.jobinrwanda.com/job/legal-counsel 37
# https://www.jobinrwanda.com/job/operations-manager-16 38
# https://www.jobinrwanda.com/job/marketing-and-communication-senior-officer 39
# https://www.jobinrwanda.com/job/partnership-senior-officer 40
# https://www.jobinrwanda.com/job/head-monitoring-evaluation 41
# https://www.jobinrwanda.com/job/lecturers-hospitality-management 42
# https://www.jobinrwanda.com/job/lecturer-tourism-studies 43
# https://www.jobinrwanda.com/job/lecturer-transport-logistics-management 44
# https://www.jobinrwanda.com/job/lecturers-business-information-technology-and-computer-engineering 45
# https://www.jobinrwanda.com/job/lecturer-business-management-specialized-accounting-marketing-and-economics 46
# https://www.jobinrwanda.com/job/lecturer-community-development 47
# https://www.jobinrwanda.com/job/marketing-officer-4 48
# https://www.jobinrwanda.com/job/language-instructor 49
# https://www.jobinrwanda.com/job/director-ict 50
# https://www.jobinrwanda.com/job/reporting-and-planning-accountant 51
# https://www.jobinrwanda.com/job/programme-officer-research-knowledge-development 52
# https://www.jobinrwanda.com/job/quantitative-lead 53
# https://www.jobinrwanda.com/job/country-programme-manager-cpm 54
# https://www.jobinrwanda.com/job/forest-landscape-restoration-project-manager 55
# https://www.jobinrwanda.com/job/senior-auditors 56
# https://www.jobinrwanda.com/job/communication-specialist-2 57
# https://www.jobinrwanda.com/job/campus-operations-assistant 58
# https://www.jobinrwanda.com/job/postdoctoral-research-fellow-0 59
# https://www.jobinrwanda.com/job/student-services-coordinator 60
# https://www.jobinrwanda.com/job/driver-pool 61
# https://www.jobinrwanda.com/job/program-unit-manager 62
# https://www.jobinrwanda.com/job/child-rights-protection-program-manager 63
# https://www.jobinrwanda.com/job/project-director-rwanda-enhanced-early-childhood-development-outcomes 64
# https://www.jobinrwanda.com/job/branch-accounts-officer-3 65
# https://www.jobinrwanda.com/job/head-finance-3 66
# https://www.jobinrwanda.com/job/chief-party-5 67
# https://www.jobinrwanda.com/job/accountant-58 68
# https://www.jobinrwanda.com/job/sales-officer-4 69
# https://www.jobinrwanda.com/job/senior-odoocrm-business-analyst 70
# https://www.jobinrwanda.com/job/retail-manager 71
# https://www.jobinrwanda.com/job/commercial-director-1 72
# https://www.jobinrwanda.com/job/project-coordinator-17 73
# https://www.jobinrwanda.com/job/sales-manager-8 74
# https://www.jobinrwanda.com/job/team-leader-and-program-manager 75
# https://www.jobinrwanda.com/job/rwanda-people-innovations-associate 76
# https://www.jobinrwanda.com/job/global-gender-lead-fixed-term 77
# https://www.jobinrwanda.com/job/site-project-coordinator 78
# https://www.jobinrwanda.com/job/branch-coordinator 79
# https://www.jobinrwanda.com/job/program-manager-8 80
# https://www.jobinrwanda.com/job/recruitment-coordinator 81
# https://www.jobinrwanda.com/job/rwanda-seed-center-construction-qaqc-coordinator-fixed-term 82
# https://www.jobinrwanda.com/job/trade-execution-coordinator 83
# https://www.jobinrwanda.com/job/grain-inventory-management-and-warehousing 84
# https://www.jobinrwanda.com/index.php/job/bulldozer-operator 85
# https://www.jobinrwanda.com/job/sous-chef 86
# https://www.jobinrwanda.com/job/waitresses 87
# https://www.jobinrwanda.com/job/housekeeping 88
# https://www.jobinrwanda.com/job/executive-chef-1 89
# https://www.jobinrwanda.com/job/director-strategy-and-partnerships 90
# https://www.jobinrwanda.com/job/sales-specialist 91
# https://www.jobinrwanda.com/job/cultural-program-officer 92
# https://www.jobinrwanda.com/job/kepler-volleyball-head-coach 93
# https://www.jobinrwanda.com/index.php/job/burundi-monitoring-evaluation-and-learning-associate 94
# https://www.jobinrwanda.com/job/process-technician-hygiene-technology-company 95
# https://www.jobinrwanda.com/job/sports-club-manager 96
# https://www.jobinrwanda.com/job/executive-assistant-non-profit 97
# https://www.jobinrwanda.com/job/technical-advisor-health-systems-strengthening 98
# https://www.jobinrwanda.com/job/senior-associate-sustainable-health-financing 99
# https://www.jobinrwanda.com/job/program-manager-monitoring-evaluation-and-learning 100
# https://www.jobinrwanda.com/job/technical-advisor-data-scientist-and-me 101
# https://www.jobinrwanda.com/job/associate-primary-health-care 102
# https://www.jobinrwanda.com/job/customer-service-officer-microfinance 103
# https://www.jobinrwanda.com/job/maitresse-de-maternelle 104
# https://www.jobinrwanda.com/index.php/job/design-team-research-fellow 105
# https://www.jobinrwanda.com/job/global-risk-manager 106
# https://www.jobinrwanda.com/index.php/job/rwanda-office-facilitator-officer 107
# https://www.jobinrwanda.com/job/rwanda-seed-centre-construction-engineer-specialist-fixed-term 108
# https://www.jobinrwanda.com/index.php/job/une-enseignante-0 109
# https://www.jobinrwanda.com/index.php/job/rwanda-potatoes-machine-operator 110
# https://www.jobinrwanda.com/job/rwanda-commercial-farm-officer-fixed-term 111
# https://www.jobinrwanda.com/index.php/job/tax-compliance-senior-specialist 112
# https://www.jobinrwanda.com/job/nigeria-country-director 113
# https://www.jobinrwanda.com/index.php/job/global-research-and-evaluation-analyst 114
# https://www.jobinrwanda.com/index.php/job/nigeria-rural-retail-operations-specialist 115
# https://www.jobinrwanda.com/job/global-monitoring-evaluation-and-learning-director 116

# %%
job_description_raw_content = requests.get('https://www.jobinrwanda.com/job/global-remote-sensing-manager').content

# %%
job_description_raw_content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n  <head>\n    <meta charset="utf-8" />\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-42852300-1"></script>\n<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "UA-42852300-1", {"groups":"default","anonymize_ip":true,"page_path":"/403.html?page=" + document.location.pathname + document.location.search + "&from=" + document.referrer});</script>\n<link rel="canonical" href="https://www.jobinrwanda.com/job/global-remote-sensing-manager" />\n<meta name="Generator" content="Drupal 9 (https://www.drupal.org)" />\n<meta name="MobileOptimized" content="width" />\n<meta name="HandheldFriendly" content="true" />\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" />\n<meta http-equiv="x-ua-compatible" content="ie=edge" />\n<link rel="icon" href="/favicon.ico" type="image/vnd.microsoft.icon" />\n<script>window.a2a_config=window.a2a_config||{};a2a_config.callbacks=[];a2a_config.overlays=[];a2a_config.templates={};</script>\n\n    <title>Access denied | Job in Rwanda</title>\n    <link rel="stylesheet" media="all" href="/core/modules/system/css/components/ajax-progress.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/align.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/autocomplete-loading.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/fieldgroup.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/container-inline.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/clearfix.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/details.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/hidden.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/item-list.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/js.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/nowrap.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/position-container.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/progress.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/reset-appearance.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/resize.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/sticky-header.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-counter.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-report-counters.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-report-general-info.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tabledrag.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tablesort.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tree-child.module.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/libraries/jquery.select2/dist/css/select2.min.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/modules/contrib/webform/css/webform.element.select2.css?rxsj74" />\n<link rel="stylesheet" media="all" href="/libraries/jquery.intl-tel-input/build/css/intlTelInput.min.css? ...

# %%
job_description_bs = BeautifulSoup(job_description_raw_content, 'html.parser')

# %%
job_description_bs.find_all('div', class_='employer-description') #Employer Description
# Out:
# []

# %%
describe = job_description_bs.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item") #Employer Description

# %%
df['description'] = None

# %%
def get_description(job_link):
  job_description_raw_content = requests.get(f'https://www.jobinrwanda.com/{job_link}').content #request raw content
  job_description_bs = BeautifulSoup(job_description_raw_content, 'html.parser')  #pass the html raw content to beautifull soup
  job_description_bs.find_all('div', class_='employer-description') #Employer Description
  #Get the entire job description
  describe = job_description_bs.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item") #Employer Description
  description = '' #Construct an empty string to hold the paragraph
  for paragraph in describe:
    description += paragraph.getText() #Adding each paragraph we find in the job description.
  return description

# %%
for position, link in enumerate(df['link']):
  df.loc[position]['description'] = get_description(job_link=link)

# %%
df
# Out:
#                                                   link  \
# 0    /job/technical-advisor-inclusive-governancere-...
# 1                /job/digitalization-technical-advisor
# 2                          /job/sales-representative-1
# 3                  /job/quality-assurance-specialist-0
# 4                                    /job/risk-manager
# ..                                                 ...
# 112    /index.php/job/tax-compliance-senior-specialist
# 113                      /job/nigeria-country-director
# 114  /index.php/job/global-research-and-evaluation-...
# 115  /index.php/job/nigeria-rural-retail-operations...
# 116  /job/global-monitoring-evaluation-and-learning...
#
#                                                  title  \
# 0    Inclusive Governance –Technical Advisor(Re-adv...
# 1                    Digitalization Technical Advisor
# 2                                   Direct Salesperson
# 3                         Quality Assurance Specialist
# 4                                         Risk Manager
# ..                                                 ...
# 112                   Tax Compliance Senior Specialist
# 113                           Nigeria Country Director
# 114             Global Research and Evaluation Analyst
# 115         Nigeria Rural Retail Operations Specialist
# 116  Global Monitoring, Evaluation and Learning Dir...
#
#                           company_link                          company type  \
# 0          [CARE International Rwanda]        CARE International Rwanda  Job
# 1          [CARE International Rwanda]        CARE International Rwanda  Job
# 2                       [Kigali Farms]                     Kigali Farms  Job
# 3          [CARE International Rwanda]        CARE International Rwanda  Job
# 4    [Sanlam Assurances Générales Plc]  Sanlam Assurances Générales Plc  Job
# ..                                 ...                              ...  ...
# 112                    [One Acre Fund]                    One Acre Fund  Job
# 113                    [One Acre Fund]                    One Acre Fund  Job
# 114                    [One Acre Fund]                    One Acre Fund  Job
# 115                    [One Acre Fund]                    One Acre Fund  Job
# 116                    [One Acre Fund]                    One Acre Fund  Job
#
#                                            description
# 0    JOB RE-ADVERTISEMENT:  \nCARE International is...
# 1    JOB ADVERTISEMENT:  \nCARE International is se...
# 2    Direct Salesperson (Sales Hunt)\nWe’re looking...
# 3    JOB ADVERTISEMENT:  \nCARE International is se...
# 4    Sanlam Assurances Générales Plc is seeking to ...
# ..                                                 ...
# 112  About One Acre Fund\nFounded in 2006, One Acre...
# 113  About One Acre Fund\nFounded in 2006, One Acre...
# 114  About One Acre Fund\nFounded in 2006, One Acre...
# 115  About One Acre Fund\nFounded in 2006, One Acre...
# 116  About One Acre Fund\nFounded in 2006, One Acre...
#
# [117 rows x 6 columns]

# %%
tags = "#informationtechnology #technology #it #cybersecurity #tech #computerscience #programming #business #coding #innovation #software #python #information #computer #informationsecurity #security #technologynews #java #networking #hacking #programmer #linux #technologyrocks #coder #technologythesedays #cloudcomputing #education #engineering #itservices #newtechnology"

# %%
tags.split('df')
# Out:
# ['#informationtechnology #technology #it #cybersecurity #tech #computerscience #programming #business #coding #innovation #software #python #information #computer #informationsecurity #security #technologynews #java #networking #hacking #programmer #linux #technologyrocks #coder #technologythesedays #cloudcomputing #education #engineering #itservices #newtechnology']

# %%
df
# Out:
#                                                   link  \
# 0    /job/technical-advisor-inclusive-governancere-...
# 1                /job/digitalization-technical-advisor
# 2                          /job/sales-representative-1
# 3                  /job/quality-assurance-specialist-0
# 4                                    /job/risk-manager
# ..                                                 ...
# 112    /index.php/job/tax-compliance-senior-specialist
# 113                      /job/nigeria-country-director
# 114  /index.php/job/global-research-and-evaluation-...
# 115  /index.php/job/nigeria-rural-retail-operations...
# 116  /job/global-monitoring-evaluation-and-learning...
#
#                                                  title  \
# 0    Inclusive Governance –Technical Advisor(Re-adv...
# 1                    Digitalization Technical Advisor
# 2                                   Direct Salesperson
# 3                         Quality Assurance Specialist
# 4                                         Risk Manager
# ..                                                 ...
# 112                   Tax Compliance Senior Specialist
# 113                           Nigeria Country Director
# 114             Global Research and Evaluation Analyst
# 115         Nigeria Rural Retail Operations Specialist
# 116  Global Monitoring, Evaluation and Learning Dir...
#
#                           company_link                          company type  \
# 0          [CARE International Rwanda]        CARE International Rwanda  Job
# 1          [CARE International Rwanda]        CARE International Rwanda  Job
# 2                       [Kigali Farms]                     Kigali Farms  Job
# 3          [CARE International Rwanda]        CARE International Rwanda  Job
# 4    [Sanlam Assurances Générales Plc]  Sanlam Assurances Générales Plc  Job
# ..                                 ...                              ...  ...
# 112                    [One Acre Fund]                    One Acre Fund  Job
# 113                    [One Acre Fund]                    One Acre Fund  Job
# 114                    [One Acre Fund]                    One Acre Fund  Job
# 115                    [One Acre Fund]                    One Acre Fund  Job
# 116                    [One Acre Fund]                    One Acre Fund  Job
#
#                                            description
# 0    JOB RE-ADVERTISEMENT:  \nCARE International is...
# 1    JOB ADVERTISEMENT:  \nCARE International is se...
# 2    Direct Salesperson (Sales Hunt)\nWe’re looking...
# 3    JOB ADVERTISEMENT:  \nCARE International is se...
# 4    Sanlam Assurances Générales Plc is seeking to ...
# ..                                                 ...
# 112  About One Acre Fund\nFounded in 2006, One Acre...
# 113  About One Acre Fund\nFounded in 2006, One Acre...
# 114  About One Acre Fund\nFounded in 2006, One Acre...
# 115  About One Acre Fund\nFounded in 2006, One Acre...
# 116  About One Acre Fund\nFounded in 2006, One Acre...
#
# [117 rows x 6 columns]

# %%
df['description']
# Out:
# 0      JOB RE-ADVERTISEMENT:  \nCARE International is...
# 1      JOB ADVERTISEMENT:  \nCARE International is se...
# 2      Direct Salesperson (Sales Hunt)\nWe’re looking...
# 3      JOB ADVERTISEMENT:  \nCARE International is se...
# 4      Sanlam Assurances Générales Plc is seeking to ...
#                              ...
# 112    About One Acre Fund\nFounded in 2006, One Acre...
# 113    About One Acre Fund\nFounded in 2006, One Acre...
# 114    About One Acre Fund\nFounded in 2006, One Acre...
# 115    About One Acre Fund\nFounded in 2006, One Acre...
# 116    About One Acre Fund\nFounded in 2006, One Acre...
# Name: description, Length: 117, dtype: object

# %%
# !pip install -U easynmt
# Out:
# Collecting easynmt
#   Downloading EasyNMT-2.0.2.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from easynmt) (4.65.0)
# Collecting transformers<5,>=4.4 (from easynmt)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from easynmt) (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easynmt) (1.22.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from easynmt) (3.8.1)
# Collecting sentencepiece (from easynmt)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.5 MB/s eta 0:00:00
# Collecting fasttext (from easynmt)
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from easynmt) (3.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->easynmt) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->easynmt) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->easynmt) (16.0.6)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers<5,>=4.4->easynmt)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.4->easynmt) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.4->easynmt) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.4->easynmt) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5,>=4.4->easynmt) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5,>=4.4->easynmt)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5,>=4.4->easynmt)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.2 MB/s eta 0:00:00
# Collecting pybind11>=2.2 (from fasttext->easynmt)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext->easynmt) (67.7.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->easynmt) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->easynmt) (1.3.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers<5,>=4.4->easynmt) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->easynmt) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->easynmt) (1.3.0)
# Building wheels for collected packages: easynmt, fasttext
#   Building wheel for easynmt (setup.py) ... done
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19903 sha256=8112fb7184a00cd6f4e821962da6fe05839c99d90932774af46f1cd0eed57f8b
#   Stored in directory: /root/.cache/pip/wheels/ab/55/72/aba4face7eac1d7750ca700aa1797b135fb8915e949da504cc
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199773 sha256=3620a05caa41d5d194e364c23aca82fccde4502f7c9cf20c38f9e85494644716
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built easynmt fasttext
# Installing collected packages: tokenizers, sentencepiece, safetensors, pybind11, huggingface-hub, fasttext, transformers, easynmt
# Successfully installed easynmt-2.0.2 fasttext-0.9.2 huggingface-hub-0.16.4 pybind11-2.11.1 safetensors-0.3.1 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.31.0

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')
# Out:
# 11.9kB [00:00, 29.4MB/s]

# %%
sentences = df['description']

# %%
import json

# %%
content=

# %%
with open('/content/sample_data/languages.json','r+')as file_lang:
  content = file_lang.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-47e8e4d41d2f> in <cell line: 1>()
# ----> 1 with open('/content/sample_data/languages.json','r+')as file_lang:
#       2   content = file_lang.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/sample_data/languages.json'

# %%
languages_json = json.loads(content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-083dacfe7c89> in <cell line: 1>()
# ----> 1 languages_json = json.loads(content)
#
# NameError: name 'content' is not defined

# %%
languages_json[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-a5bf0115b79c> in <cell line: 1>()
# ----> 1 languages_json[1]
#
# NameError: name 'languages_json' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
languages_json[1]['code']

# %%
len(languages_json)
# Out:
# 184

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df['description'] = sentences

# %%
df
# Out:
#                                           description
# 0   On behalf of our client, We are looking for an...
# 1   Position: Account Manager- Credit\nLocations: ...
# 2   Job Description\nRegional Grants Officer, Cent...
# 3   Northern Province-Gakenke District-Gakenke Sec...
# 4   JOB OPPORTUNITY\nMonitoring, Evaluation, Accou...
# ..                                                ...
# 70  About One Acre Fund\nFounded in 2006, One Acre...
# 71  About One Acre Fund\nFounded in 2006, One Acre...
# 72  About One Acre Fund\nFounded in 2006, One Acre...
# 73  About One Acre Fund\nFounded in 2006, One Acre...
# 74  ABOUT ONE ACRE FUND\nFounded in 2006, One Acre...
#
# [75 rows x 1 columns]

# %%
for language in languages_json[80:100]:
  code = language['code']
  name = language['name']
  try:
   df[name] = model.translate(sentences, source_lang='en', target_lang=code)
  except:
    pass
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading:   0%|          | 0.00/812k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/810k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/303M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/606k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/276M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/664k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/282M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/825k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/303M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/823k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/811k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/298M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/800k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/829k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/302M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/362k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/204M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/799k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.00M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.35M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/306M [00:00<?, ?B/s]

# %%
df

# %%
df['description']
# Out:
# 0     RE-ADVERTISEMENT OF TENDER : Nº: 022/10/2022/B...
# 1     RE-ADVERTISEMENT OF TENDER : RFP No. 017/08/20...
# 2     TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 3     Expression of Interest (EOI) Event management ...
# 4     TERMS OF REFERENCE\nRecruitment of (a) Consult...
#                             ...
# 69                                                 None
# 70                                                 None
# 71                                                 None
# 72                                                 None
# 73                                                 None
# Name: description, Length: 74, dtype: object

# %% [markdown]
# CONSULTANCY_JOBS IN RWANDA

# %%
content_cons

# %%
page = BeautifulSoup(content_cons, 'html.parser')

# %%
advertse = page.find_all('div', class_='card-body p-2')

# %%
advertse[0]

# %%
advertse[0].find('p').find('br')

# %%
advertse[0].find('span').getText() #Title of Each Job advert
advertse[0].find('a')['href']  #Link to the content of each job title
advertse[0].find('p').find('a') #Link to the Institution that has posted the advert
advertse[0].find('p').find('a').getText() #This is the name of the company
# Out:
# 'Development Bank of Rwanda (BRD)'

# %%
import pandas as pd

# %%
dfs = pd.DataFrame()
dfs['link'] = None
dfs['title'] = None
dfs['company_link'] = None
dfs['company'] = None
dfs['type'] = None

# %%
l = ['a', 'v', 'b']
for index, item in enumerate(l):
  print(index, item)

# %%
l[0]

# %%
def parse_content(content, advert_type):
  link = []
  title = []
  company = []
  company_link = []
  job_type = []
  for index, advert in enumerate(content):
    link.append(advert.find('a')['href'])
    title.append(advert.find('span').getText()) #GEt the title from
    company.append(str(advert.find('p').find('a').getText()))
    company_link.append(advert.find('p').find('a'))
    job_type.append(advert_type) #Whether its a job/consultacy/tender
  return link, title, company, company_link, job_type

# %%
content_cons_bs = BeautifulSoup(content_cons, 'html.parser')
content_cons_titles = content_cons_bs.find_all('div', class_='card-body p-2')
dfs['link'], dfs['title'], dfs['company'], dfs['company_link'], dfs['type']= parse_content(content_cons_titles, advert_type='Job')

# %%
dfs['link']

# %%
list_description = []
for i in range(len(dfs)):
  link = 'https://www.jobinrwanda.com' + dfs['link'][i]
  print(link, i)

# %%
job_description_raw_content

# %%
job_description_bs = BeautifulSoup(job_description_raw_content, 'html.parser')

# %%
job_description_bs.find_all('div', class_='employer-description')

# %%
describe = job_description_bs.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item")

# %%
def get_description(job_link):
  job_description_raw_content = requests.get(f'https://www.jobinrwanda.com/{job_link}').content #request raw content
  job_description_bs = BeautifulSoup(job_description_raw_content, 'html.parser')  #pass the html raw content to beautifull soup
  job_description_bs.find_all('div', class_='employer-description') #Employer Description
  #Get the entire job description
  describe = job_description_bs.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item") #Employer Description
  description = '' #Construct an empty string to hold the paragraph
  for paragraph in describe:
    description += paragraph.getText() #Adding each paragraph we find in the job description.
  return description

# %%
for position, link in enumerate(dfs['link']):
  dfs.loc[position]['description'] = get_description(job_link=link)

# %%
dfs

# %%
dfs['description']
# Out:
# 0     RE-ADVERTISEMENT OF TENDER : Nº: 022/10/2022/B...
# 1     RE-ADVERTISEMENT OF TENDER : RFP No. 017/08/20...
# 2     TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 3     Expression of Interest (EOI) Event management ...
# 4     TERMS OF REFERENCE\nRecruitment of (a) Consult...
# 5     TENDER ANNOUNCEMENT\nTITLE:  Consultancy Servi...
# 6     Job description: short term national expert to...
# 7     United  Nations\nCORE VALUES: INTEGRITY, PROFE...
# 8     CONSULTANT SERVICES TO CONDUCT IMPACT ASSESSEM...
# 9     \n\nINGOBYI ACTIVITY\nGOLDEN PLAZA, 3rd Floor\...
# 10    About One Acre Fund\nFounded in 2006, One Acre...
# 11    (Re-advertisement)\nExpression of Interest (EO...
# 12    Advertisement for Consultancy service To Organ...
# 13    Terms of Reference (ToR) for the recruitment o...
# 14    CONSULTANCY TO CONDUCT NEEDS ASSESSMENT STUDY ...
# 15    Description of the assignment: HIRING OF NATIO...
# 16    Job description: Training Expert to provide tr...
# 17    Terms of Reference for conducting a market lan...
# 18    Terms of Reference\nDOCUMENTARY FILM PRODUCTIO...
# 19    Terms of Reference\nPROGRAMME BRIEF WRITING fo...
# 20    Terms of Reference\nMIDLINE REPORT WRITING for...
# 21    Advertisement for Procurement\nRequest for Pro...
# 22    Terms of Reference for Consultant\nConsultancy...
# 23    Short Term Consultancy to Develop Tailored Loa...
# 24    CONSULTANT TO CONDUCT A BASELINE SURVEY FOR EV...
# Name: description, dtype: object

# %%
content_tenders = requests.get('https://www.umucyo.gov.rw/').content #Tenders

# %%
content_tenders

# %%
page = BeautifulSoup(content_tenders, 'html.parser')

# %%
advertsiment = page.find_all('div', class_='card-body p-2')
